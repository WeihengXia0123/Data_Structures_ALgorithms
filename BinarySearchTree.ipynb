# %%
class Node(object):
    def __init__(self, value):
        self.value = value
        self.left = None
        self.right = None

class BST(object):
    def __init__(self, root):
        self.root = Node(root)

    def insert(self, new_val):
        insert_node = self.root
        
        while(insert_node != None):
            if(insert_node.value < new_val):
                if insert_node.right == None:
                    insert_node.right = Node(new_val)
                    break
                else:
                    insert_node = insert_node.right

            elif(insert_node.value == new_val):
                print("new value already existed in the tree")
                break
            
            elif(insert_node.value > new_val):
                if insert_node.left == None:
                    insert_node.left = Node(new_val)
                    break
                else:
                    insert_node = insert_node.left
                    
    def insert_recursive(self, current_node, new_val):
        if current_node:
            if new_val < current_node.value:
                if current_node.left:
                    self.insert_recursive(current_node.left, new_val)
                else:
                    current_node.left = Node(new_val)
            if new_val == current_node.value:
                print("new_val already existed")
                return False
            if new_val > current_node.value:
                if current_node.right:
                    self.insert_recursive(current_node.right, new_val)
                else:
                    current_node.right = Node(new_val)
        else:
            current_node = Node(new_val)
        
    def search(self, find_val):
        current = self.root
        
        while(current):
            if(find_val < current.value):
                if(current.left):
                    current = current.left
                else:
                    return False
            elif(find_val == current.value):
                return True
            elif(find_val > current.value):
                if(current.right):
                    current = current.right
                else:
                    return False
        return False
    
    def search_recursive(self, start, find_val):
        if find_val < start.value:
            if start.left:
                return self.search_recursive(start.left, find_val)
            else:
                return False
        elif find_val == start.value:
            return True
        elif find_val > start.value:
            if start.right:
                return self.search_recursive(start.right, find_val)
            else:
                return False
        
    def print_tree(self):
        print(self.preorder_print(self.root, "")[:-1])
        
    def preorder_print(self, start, traversal):
        if start:
            traversal += (str(start.value) + "-")
            traversal = self.preorder_print(start.left, traversal)
            traversal = self.preorder_print(start.right, traversal)
        return traversal
        
        
# Set up tree
tree = BST(4)

# Insert elements
tree.insert(2)
tree.insert(1)
tree.insert(3)
tree.insert(5)
tree.insert_recursive(tree.root, 11)
tree.insert_recursive(tree.root, 13)
tree.insert_recursive(tree.root, 15)


tree.print_tree()
# Check search
# Should be True
# print tree.search(4)
print tree.search_recursive(tree.root, 4)
print tree.search_recursive(tree.root, 2)
print tree.search_recursive(tree.root, 5)
# Should be False
print tree.search_recursive(tree.root, 6)
print tree.search(6)
# Out:
# 4-2-1-3-5-11-13-15
# True
# True
# True
# False
# False
